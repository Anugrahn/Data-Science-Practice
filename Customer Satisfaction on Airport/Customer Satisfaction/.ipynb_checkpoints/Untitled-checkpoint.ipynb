# %%
import pandas as pd
import numpy as np 
import seaborn as sns

# %%
pd.set_option('max_columns',100)
df = pd.read_csv('Cust_Satisfaction_SampleClean.csv').drop('Unnamed: 0',axis=1)

# %%
df.head()
# Out:
#        id satisfaction_v2  Gender   Customer Type  Age   Type of Travel  \
# 0  110278       satisfied    Male  Loyal Customer   47  Personal Travel
# 1  103199       satisfied  Female  Loyal Customer   15  Personal Travel
# 2  100744       satisfied    Male  Loyal Customer   30  Personal Travel
# 3   32838       satisfied  Female  Loyal Customer   66  Personal Travel
# 4   32864       satisfied    Male  Loyal Customer   10  Personal Travel
#
#       Class  Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0  Business             2464             0                                  0
# 1       Eco             2138             0                                  0
# 2       Eco             1894             0                                  0
# 3       Eco              227             0                                  0
# 4       Eco             1812             0                                  0
#
#    Food and drink  Gate location  Inflight wifi service  \
# ...

# %%
df.satisfaction_v2.value_counts()
# Out:
# satisfied                  35602
# neutral or dissatisfied    29338
# Name: satisfaction_v2, dtype: int64

# %%
df[df['satisfaction_v2'] == 'neutral or dissatisfied'].head()
# Out:
#          id          satisfaction_v2 Gender   Customer Type  Age  \
# 395  123730  neutral or dissatisfied   Male  Loyal Customer   48
# 398   32873  neutral or dissatisfied   Male  Loyal Customer   30
# 401   87865  neutral or dissatisfied   Male  Loyal Customer   19
# 402   46711  neutral or dissatisfied   Male  Loyal Customer   13
# 403  126758  neutral or dissatisfied   Male  Loyal Customer   60
#
#       Type of Travel     Class  Flight Distance  Seat comfort  \
# 395  Personal Travel  Eco Plus             1201             1
# 398  Personal Travel       Eco             1582             1
# 401  Personal Travel       Eco             1737             1
# 402  Personal Travel       Eco             1351             1
# 403  Personal Travel       Eco             3434             1
#
#      Departure/Arrival time convenient  Food and drink  Gate location  \
# 395                                  0               0              1
# ...

# %%
df['Average Rating'] = (df.iloc[:, -16:-2].sum(axis=1))/16

# %%
len(df[df['Average Rating'] >3])
# Out:
# 27837

# %%
len(df[(df['Average Rating'] <=3)])
# Out:
# 37103

# %%
len(df[(df['Average Rating'] <=2.5)])
# Out:
# 17727

# %%
37103-17727
# Out:
# 19376

# %%
37103+27837
# Out:
# 64940

# %%
len(df[(df['Average Rating'] >=3.5) & (df['satisfaction_v2'] == 'neutral or dissatisfied' )])
# Out:
# 1011
